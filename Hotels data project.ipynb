# %% [markdown]
# <font size = '12'><font color = 'sky blue'><b>Python Project - Hotels in India

# %% [markdown]
# <font color = 'red'><b>Importing Python libraries to perform Data Exploring and Cleaning.</b></font>
# <ul style ='list-style-type'>For performing Data Exploring Pandas lib is enough.</ul>
# <ul style ='list-style-type'>If you wise to create graph and chart then you have to import Seaborn and Matplot.</ul>
# <ul style ='list-style-type'>In this project I have import all lib for Data Analytics. </ul>

# %%
import pandas as pd
import matplotlib.pylab as mtp
import seaborn as sns 
import numpy as np

# %% [markdown]
# <font color = 'red'><b>Creating a Data Frame and assigning the csv file to Data Frame</font></b>
# <ul><font color='green'>df</font> a is variable which stores the csv file</ul>
# <ul><font color='green'>pd.read_csv()</font> is used to read the csv file in the folder selected</ul>
# <ul>It is case sensitive, you have to enter correctly orelse it will throw a error</ul>

# %%
df=pd.read_csv('csv_data.csv')

# %% [markdown]
# <ul><font color='green'>df.head() </font>will give you the first 5 rows from the data by dedault.</ul>
# <ul>You can specify the no. rows by giving it in the function. <font color='green'>i.e df.head(10)</ul></font>

# %%
df.head()
# Out:
#    S.No.    State       City Category Alcohol  \
# 0      1    Delhi  New Delhi   1 Star     NaN
# 1      2  Gujarat     Adalaj   1 Star     NaN
# 2      3  Gujarat  Ahmedabad   1 Star     NaN
# 3      4  Gujarat  Ahmedabad   1 Star     NaN
# 4      5  Gujarat      Anand   1 Star     NaN
#
#                                           Hotel Name  \
# 0  Hotel LA (A unit of L A Hotels And Retreats Pv...
# 1  Amba Suites, Unit of Amba Township Private Lim...
# 2  Hotel Pragati The Grand (A Unit of Pragati The...
# 3                                       Hotel Rezaas
# 4                                  HOTEL ARIZONA INN
#
#                                              Address  Start Date Expiry Date  \
# 0  plot no A-1, Community Centre, Road No 43, Man...  20-01-2020  19-01-2025
# 1  Amba Business Park, Shivam – II, Sub-Plot No. ...  15-07-2022  14-07-2027
# 2  SP-2,FP 2342,PAIKI, NR ZYDUS CADILA HOSPITAL,H...  22-09-2021  21-09-2026
# ...

# %% [markdown]
# <ul><font color='green'>df.tail()</font> is same as head() because  it give the last 5 rows of the data by default.</ul>
# <ul>You can also specify tail()</ul>

# %%
df.tail()
# Out:
#       S.No.        State      City Category          Alcohol  \
# 1207   1208  Maharashtra    MUMBAI   5 Star  Without Alcohol
# 1208   1209  Uttarakhand  Dehradun   5 Star  Without Alcohol
# 1209   1210  West Bengal  Durgapur   5 Star  Without Alcohol
# 1210   1211  West Bengal   Kolkata   5 Star  Without Alcohol
# 1211   1212  West Bengal  Siliguri   5 Star  Without Alcohol
#
#                                              Hotel Name  \
# 1207                       RADISSON MUMBAI ANDHERI MIDC
# 1208                          Seyfert Sarovar Premiere
# 1209  FORTUNE PARK PUSHPANJALI- MEMBER ITC'S HOTEL G...
# 1210                          Raajkutir IHCL SeleQtions
# 1211                     COURTYARD BY MARRIOTT SILIGURI
#
#                                                 Address  Start Date  \
# 1207  X-22, MIDC CENTRAL ROAD, ANDHERI EAST, MUMBAI ...  18-10-2018
# 1208  Khasra No 270, Haridwar Bypass Road, Dehradun,...  25-02-2019
# ...

# %% [markdown]
# <font color='red'><b>Checking duplicates in Data</font></b>
# <ul><font color='green'>duplicated()</font> will check the duplicate values in data and gives it in boolean output</ul>
# <ul>To get number value I have used <font color='green'>sum()</font> to get sum of True </ul>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <font color='red'><b>Checking the shape of the Data</font></b>
# <ul>Shape give the (no.rows, no.column)

# %%
df.shape
# Out:
# (1212, 10)

# %% [markdown]
# <font color='red'><b>Data Information</font></b>
# <ul>This shows the Column name, Non-Null count, Datatype</ul>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   S.No.        1212 non-null   int64
#  1   State        1212 non-null   object
#  2   City         1212 non-null   object
#  3   Category     1212 non-null   object
#  4   Alcohol      676 non-null    object
#  5   Hotel Name   1212 non-null   object
#  6   Address      1212 non-null   object
#  7   Start Date   1212 non-null   object
#  8   Expiry Date  1212 non-null   object
#  9   Total Rooms  1212 non-null   int64
# dtypes: int64(2), object(8)
# memory usage: 94.8+ KB

# %% [markdown]
# <font color='red'><b>Checking the no. of null values</font></b>
# <ul>From the info() we can find that Alcohol column has some null values</ul>
# <ul>We can specify the column as <font color='green'>df['Alcohol']</font></ul>
# <ul><font color='green'>isnull()</font> will check for null values and gives boolean output</ul>
# <ul><font color='green'>sum()</font> will give the sum of True

# %%
df['Alcohol'].isnull().sum()
# Out:
# 536

# %% [markdown]
# <font color='red'><b>Filling the NaN places with valid terms</b></font>
# <ul><font color='green'>Fillna()</font> will fill NaN places with 'Without Alcohol'</ul>
# <ul><font color='green'>inplace=True</font> will update the data with the changes</ul>

# %%
df['Alcohol'].fillna('Without Alcohol', inplace=True)

# %% [markdown]
# <font color='red'><b>Checking the changes</font></b>
# <ul>All NaN values have changed to 'Without Alcohol'</ul>

# %%
df['Alcohol']
# Out:
# 0       Without Alcohol
# 1       Without Alcohol
# 2       Without Alcohol
# 3       Without Alcohol
# 4       Without Alcohol
#              ...
# 1207    Without Alcohol
# 1208    Without Alcohol
# 1209    Without Alcohol
# 1210    Without Alcohol
# 1211    Without Alcohol
# Name: Alcohol, Length: 1212, dtype: object

# %%
df['Alcohol'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <font color='sky blue'><b>Data Analysing</font></b>
# <ul><font color='red'><b>No. of Hotels With Alcohol and Without Alcohol</b></font></ul>

# %%
df['Alcohol'].value_counts()
# Out:
# Alcohol
# Without Alcohol    720
# With Alcohol       492
# Name: count, dtype: int64

# %% [markdown]
# <ul><font color='red'><b>No. of Hotels With Total Rooms</b></font></ul>

# %%
df['Total Rooms'].value_counts().sort_values(ascending=False)
# Out:
# Total Rooms
# 10     127
# 11      75
# 12      44
# 20      33
# 19      26
#       ...
# 354      1
# 493      1
# 600      1
# 368      1
# 123      1
# Name: count, Length: 253, dtype: int64

# %% [markdown]
# <ul><font color='red'><b>No. of Hotels by Category</b></font></ul>

# %%
df['Category'].value_counts()
# Out:
# Category
# 3 Star    497
# 4 Star    338
# 5 Star    338
# 2 Star     23
# 1 Star     16
# Name: count, dtype: int64

# %% [markdown]
# <ul><font color='red'><b>No. of Hotels in each State</b></font></ul>

# %%
df['State'].value_counts()
# Out:
# State
# Kerala                 557
# Gujarat                144
# Maharashtra             81
# West Bengal             47
# Delhi                   42
# Karnataka               39
# Goa                     38
# Andhra Pradesh          32
# Haryana                 28
# Chhattisgarh            27
# Tamil Nadu              26
# Telangana               21
# Rajasthan               20
# Uttar Pradesh           19
# Madhya Pradesh          16
# Assam                   16
# Odisha                  15
# Punjab                  12
# Uttarakhand              7
# Himachal Pradesh         5
# Andaman And Nicobar      4
# Bihar                    3
# Arunachal Pradesh        3
# DNH & DD                 2
# Jharkhand                2
# Chandigarh               2
# Meghalaya                1
# Manipur                  1
# Tripura                  1
# Ladakh                   1
# Name: count, dtype: int64

# %% [markdown]
# <ul><font color='red'><b>Hotels in multiple address</b></font></ul>

# %%
df['Hotel Name'].value_counts()
# Out:
# Hotel Name
# Park Residency                    4
# HOTEL INDRAPRASTHA                4
# Hotel Zodiac                      3
# Hotel Park Residency              3
# Ramee Guestline Hotel             2
#                                  ..
# PADMASREE TOURIST HOME            1
# Leela Backwaters Inn              1
# Hotel Safari                      1
# HOTEL PRASANTHI                   1
# COURTYARD BY MARRIOTT SILIGURI    1
# Name: count, Length: 1185, dtype: int64

# %% [markdown]
# <ul><font color='red'><b>No. of Hotels in each cities</b></font></ul>

# %%
df['City'].value_counts()
# Out:
# City
# Ernakulam             100
# Thiruvananthapuram     58
# Thrissur               57
# Kollam                 43
# Mumbai                 39
#                      ...
# Punalur                 1
# Ponnani                 1
# Pattambi                1
# Ottappalam              1
# Siliguri                1
# Name: count, Length: 247, dtype: int64

# %% [markdown]
# <ul><font color='red'><b>Drilling down to State wise Hotel details</b></font></ul>

# %%
df.groupby(['State','Category','Alcohol']).size().sort_values(ascending=False)
# Out:
# State                Category  Alcohol
# Kerala               3 Star    Without Alcohol    305
#                      4 Star    With Alcohol       112
#                                Without Alcohol     96
# Gujarat              3 Star    Without Alcohol     62
# Maharashtra          5 Star    With Alcohol        34
#                                                  ...
# Odisha               4 Star    Without Alcohol      1
# Punjab               4 Star    With Alcohol         1
# Rajasthan            2 Star    Without Alcohol      1
# Delhi                1 Star    Without Alcohol      1
# Andaman And Nicobar  2 Star    Without Alcohol      1
# Length: 98, dtype: int64

# %% [markdown]
# <ul><font color ='red'><b>No.of Hotels in cities with states</font></b></ul>

# %%
df.groupby(['State','City']).size().sort_values(ascending=False)
# Out:
# State        City
# Kerala       Ernakulam             100
#              Thiruvananthapuram     58
#              Thrissur               57
#              Kollam                 43
# Maharashtra  Mumbai                 39
#                                   ...
# Kerala       Valancherry             1
# Gujarat      Nadiad                  1
#              Navsari                 1
# Kerala       Thripunithura           1
# West Bengal  Siliguri                1
# Length: 247, dtype: int64

# %% [markdown]
# <ul><font color='red'><b>Overall view of the Data</b></font></ul>

# %%
print(df[['Hotel Name','Alcohol','State','Category','Total Rooms']].sort_values('Total Rooms',ascending=False).to_string(index=False,justify='center'))
# Out:
#                                               Hotel Name                                                   Alcohol            State        Category  Total Rooms
#                                                                                    Hyatt Regency Delhi    With Alcohol               Delhi  5 Star      1024
#                                                                                        ITC GRAND CHOLA    With Alcohol          Tamil Nadu  5 Star       600
#                                                                         JW Marriott Hotel Mumbai Sahar    With Alcohol         Maharashtra  5 Star       588
#                                                                                 Trident, Nariman Point    With Alcohol         Maharashtra  5 Star       555
#                                                                                        The Ashok Hotel    With Alcohol               Delhi  5 Star       550
# ...
